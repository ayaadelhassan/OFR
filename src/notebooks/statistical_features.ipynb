# %%
import numpy as np
from preprocessing import *
from math import sin,cos,pi
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
import os
from itertools import chain, combinations

# %%
def get_Reference_Line(binarized):
    hist = np.sum(1-binarized/255,axis=1)
    referenceline = np.argmax(hist)
    return referenceline

def get_BlackWhiteRatio(binarized):
    hImg, wImg = binarized.shape
    blackCount = np.sum(binarized==0)
    whiteCount = max(1,np.sum(binarized==255))
    return blackCount/whiteCount

def get_Components(binarized):
    contours,_ = cv2.findContours(255-binarized, cv2.RETR_EXTERNAL,  cv2.CHAIN_APPROX_NONE)
    return contours,len(contours)

def get_CountContours(contours,referenceline):
    countAbove,countBelow=0,0
    for cnt in contours:
        x,y,w,h  = cv2.boundingRect(cnt)
        if y+h <= referenceline:countAbove+=1
        if y > referenceline:countBelow+=1
        
    return countAbove,countBelow

def dist(x, y, x1, y1):
    return ((x - x1)**2)**(0.5) + ((y - y1)**2) ** (0.5)

def get_Orientation(contours,binarized):
    hImg, wImg = binarized.shape
    test = np.zeros((hImg,wImg,3))
    test[:,:,0] = binarized
    test[:,:,1] = binarized
    test[:,:,2] = binarized
    anglesSum = 0
    for cnt in contours:
        if cnt.shape[0] > 5:
            x,y,_,_  = cv2.boundingRect(cnt)
            ellipse = cv2.fitEllipse(cnt)
            (xc,yc),(d1,d2),angle = ellipse
            angle = 90 - angle
            anglesSum += angle
            cv2.putText(test,f'{int(angle)}',(x,y),0,0.25,(0,0,255)) 
            cv2.ellipse(test, ellipse, (255,0, 255), 1, cv2.LINE_AA)
    anglesMean = anglesSum/len(contours)
    cv2.imwrite("withEllipses.png", test)
    return anglesMean
def getHVSL(edge_image, img, name=""):
    fld = cv2.ximgproc.createFastLineDetector()
    lines = fld.detect(edge_image.astype('uint8'))
    no_of_horizontal_lines = 0.0
    no_of_vertical_lines = 0.0
    for line in lines:
        x0 = int(round(line[0][0]))
        y0 = int(round(line[0][1]))
        x1 = int(round(line[0][2]))
        y1 = int(round(line[0][3]))
        d = dist(x0, y0, x1, y1)
        if d > 10: #You can adjust the distance
            if np.abs(x0 - x1) >= 0 and np.abs(x0 - x1) <= 3:
                no_of_vertical_lines += 1 
                #cv2.line(img, (x0, y0), (x1, y1), (255, 0, 0), 1, cv2.LINE_AA)
            if np.abs(y0 - y1) >= 0 and np.abs(y0 - y1) <= 3:
                no_of_horizontal_lines += 1
                #cv2.line(img, (x0, y0), (x1, y1), (0, 0, 255), 1, cv2.LINE_AA)
    if no_of_horizontal_lines == 0:
        no_of_horizontal_lines = 1
    return no_of_vertical_lines,no_of_horizontal_lines

def LaplacianEdge(img_binary,name=""):
    kernel_size = 3
    ddepth = cv2.CV_16S
    img_edge = cv2.Laplacian(img_binary, ddepth, ksize=kernel_size)
    img_edge = 255 - img_edge
    #cv2.imwrite(f"output/{name}_final_otsu.png",img_edge)
    return img_edge

def get_Features(binarized):
    hImg, wImg = binarized.shape

    referenceline = get_Reference_Line(binarized)
    blackwhiteRatioTotal = get_BlackWhiteRatio(binarized)

    imgAboveRef = binarized[:referenceline,:]
    imgBelowRef = binarized[referenceline:,:]

    blackwhiteRatioAbove = get_BlackWhiteRatio(imgAboveRef)
    blackwhiteRatioBelow = get_BlackWhiteRatio(imgBelowRef)

    contoursTotal, contoursTotalCount = get_Components(binarized)

    contoursAboveCount,contoursBelowCount = get_CountContours(contoursTotal,referenceline)
    DenistyAbove = contoursAboveCount/contoursTotalCount
    DenistyBelow = contoursBelowCount/contoursTotalCount
    orientation = get_Orientation(contoursTotal,binarized)
    
    #########aya
    edges = LaplacianEdge(binarized)
    
    verticalCount,horizontalCount = getHVSL(edges, img, name="")
    

    features = [referenceline/hImg,blackwhiteRatioTotal,blackwhiteRatioAbove,blackwhiteRatioBelow,orientation,DenistyAbove,DenistyBelow,verticalCount,horizontalCount]
    return features

# %%
base_dir='ACdata_base/'

fonts = os.listdir(base_dir)
X=[]
Y=[]
for font in fonts:
    data = os.listdir(base_dir+font)
    print("curFont",font)
    for img in data:
        img_dir = base_dir+font+'/'+img
        imgGray = cv2.imread(img_dir, cv2.IMREAD_GRAYSCALE)
        binarizedImg =  Binarize_Histogram(imgGray,img_dir)
        features = get_Features(binarizedImg)
        X.append(features)
        Y.append(int(font))
# Out:
# curFont 8
# curFont 5
# curFont 6
# curFont 7
# curFont 9
# curFont 3
# curFont 2
# curFont 1
# curFont 4

# %%
X = np.array(X)
Y = np.array(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=4, stratify=Y)
clf_tree = DecisionTreeClassifier(max_depth=9, random_state=1)
clf_tree = clf_tree.fit(x_train, y_train)
print("Finished Fitting Tree")
y_pred_test = clf_tree.predict(x_test)
accuracy_test = np.mean(y_test==y_pred_test)
y_pred_train = clf_tree.predict(x_train)
accuracy_train = np.mean(y_train==y_pred_train)
print(f"Tree :  accuracy_train: {accuracy_train}, accuracy_test: {accuracy_test} ")
# Out:
# Finished Fitting Tree
# Tree :  accuracy_train: 0.8907363420427553, accuracy_test: 0.6706161137440758

# %%
def Train_NN(X,Y,hidden):
    print("Start Training ")
    N = len(X[0])
    X = np.array(X)
    Y = np.array(Y)
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=4, stratify=Y)
    clf = MLPClassifier(alpha=1e-05, hidden_layer_sizes=(hidden),random_state=1,solver='lbfgs',max_iter=10000)
    clf = clf.fit(x_train, y_train)
    print("Finished Fitting")
    y_pred_test = clf.predict(x_test)
    accuracy_test = np.mean(y_test==y_pred_test) * 100
    
    y_pred_train = clf.predict(x_train)
    accuracy_train = np.mean(y_train==y_pred_train) * 100
    print(f"accuracy_train: {accuracy_train}, accuracy_test: {accuracy_test} with {N} features and {hidden} layers" )
    return accuracy_train,accuracy_test

# %%
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))
N = len(X[0])
features_x = list(range(N))
features_powerset = list(powerset(features_x))

# %%
def reduce_features(X,featureset):
    Xnew=[]
    featureset = list(featureset)
    for x in X:
        Xnew.append(x[featureset])
    return Xnew


accuracies=[]
for featureset in features_powerset:
    accuracy_set=0
    if len(featureset)>0:
        newX = reduce_features(X,featureset)
#         print("newX",newX)
        #N = len(newX[0])
        #for i in range(N,N*2):
        accuracy = Train_NN(newX,Y,9)
        accuracies.append(accuracy)
# Out:
# Start Training
# Finished Fitting
# accuracy_train: 26.207442596991292, accuracy_test: 26.540284360189574 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 45.209817893903406, accuracy_test: 42.89099526066351 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 42.517814726840854, accuracy_test: 38.62559241706161 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 39.82581155977831, accuracy_test: 34.360189573459714 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 34.52098178939034, accuracy_test: 33.175355450236964 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 32.779097387173394, accuracy_test: 36.72985781990521 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 23.198733174980205, accuracy_test: 20.85308056872038 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 1 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 47.42676167854315, accuracy_test: 42.41706161137441 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 47.980997624703086, accuracy_test: 43.60189573459716 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 41.72604908946952, accuracy_test: 38.15165876777251 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 45.288994457640534, accuracy_test: 42.65402843601896 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.4972288202692, accuracy_test: 43.3649289099526 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 37.212984956452885, accuracy_test: 34.12322274881517 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 26.920031670625495, accuracy_test: 24.407582938388625 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 34.99604117181314, accuracy_test: 35.308056872037916 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.681710213776725, accuracy_test: 52.3696682464455 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.76088677751386, accuracy_test: 53.55450236966824 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.87806809184482, accuracy_test: 57.81990521327014 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.06571654790183, accuracy_test: 56.39810426540285 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 46.00158353127474, accuracy_test: 43.3649289099526 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.418052256532064, accuracy_test: 43.838862559241704 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 51.93982581155978, accuracy_test: 45.97156398104265 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.34441805225653, accuracy_test: 54.502369668246445 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 54.63182897862233, accuracy_test: 53.55450236966824 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.90736342042755, accuracy_test: 55.21327014218009 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 48.77276326207443, accuracy_test: 44.07582938388626 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 49.96041171813143, accuracy_test: 44.07582938388626 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 48.614410134600156, accuracy_test: 42.18009478672986 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 54.47347585114806, accuracy_test: 53.79146919431279 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 51.306413301662715, accuracy_test: 45.26066350710901 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 45.447347585114805, accuracy_test: 39.09952606635071 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 47.82264449722882, accuracy_test: 43.60189573459716 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.0221694378464, accuracy_test: 40.99526066350711 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 48.851939825811556, accuracy_test: 47.6303317535545 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 42.59699129057799, accuracy_test: 40.047393364928915 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 49.6437054631829, accuracy_test: 43.127962085308056 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.972288202692, accuracy_test: 42.41706161137441 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 43.942992874109265, accuracy_test: 40.28436018957346 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 28.26603325415677, accuracy_test: 28.436018957345972 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 43.547110055423595, accuracy_test: 40.047393364928915 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 27.23673792557403, accuracy_test: 24.644549763033176 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 36.65874901029295, accuracy_test: 35.308056872037916 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 42.75534441805225, accuracy_test: 42.65402843601896 with 2 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.30324623911323, accuracy_test: 55.45023696682464 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.33887569279493, accuracy_test: 43.127962085308056 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.77830562153602, accuracy_test: 55.45023696682464 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.391132224861444, accuracy_test: 60.90047393364929 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 50.91053048297704, accuracy_test: 47.1563981042654 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.40300870942201, accuracy_test: 51.18483412322274 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.58194774346793, accuracy_test: 49.28909952606635 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 48.614410134600156, accuracy_test: 43.838862559241704 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.561361836896275, accuracy_test: 50.71090047393365 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.10372129849564, accuracy_test: 57.10900473933649 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 50.19794140934284, accuracy_test: 45.26066350710901 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 51.14806017418844, accuracy_test: 47.867298578199055 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 52.810768012668255, accuracy_test: 50.0 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 54.156769596199524, accuracy_test: 52.3696682464455 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.87806809184482, accuracy_test: 51.65876777251185 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 47.03087885985748, accuracy_test: 40.28436018957346 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 47.66429136975455, accuracy_test: 41.70616113744076 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 50.27711797307997, accuracy_test: 45.26066350710901 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.00712589073634, accuracy_test: 54.02843601895735 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 49.16864608076009, accuracy_test: 47.1563981042654 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 50.3562945368171, accuracy_test: 46.208530805687204 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 51.86064924782264, accuracy_test: 45.7345971563981 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.2652414885194, accuracy_test: 51.8957345971564 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 50.1187648456057, accuracy_test: 43.3649289099526 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 51.22723673792557, accuracy_test: 45.023696682464454 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 38.71733966745843, accuracy_test: 37.677725118483416 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 40.38004750593824, accuracy_test: 36.492890995260666 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.7347585114806, accuracy_test: 42.65402843601896 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.24465558194775, accuracy_test: 55.21327014218009 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.866191607284236, accuracy_test: 63.03317535545023 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.49960411718132, accuracy_test: 59.71563981042654 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.84006334125099, accuracy_test: 52.843601895734594 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 52.96912114014252, accuracy_test: 46.682464454976305 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.27395091053048, accuracy_test: 56.39810426540285 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.57878068091844, accuracy_test: 63.03317535545023 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.66666666666666, accuracy_test: 63.270142180094794 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.2652414885194, accuracy_test: 53.317535545023695 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.89865399841647, accuracy_test: 52.13270142180095 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.14489311163895, accuracy_test: 58.767772511848335 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.6959619952494, accuracy_test: 65.87677725118483 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.04513064133017, accuracy_test: 59.71563981042654 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.32066508313538, accuracy_test: 61.61137440758294 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.520190023752974, accuracy_test: 55.45023696682464 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.19160728424386, accuracy_test: 63.03317535545023 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.8456057007126, accuracy_test: 60.90047393364929 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.90736342042755, accuracy_test: 54.2654028436019 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.681710213776725, accuracy_test: 49.763033175355446 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.12747426761678, accuracy_test: 50.23696682464455 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.20348376880443, accuracy_test: 53.317535545023695 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.895486935866984, accuracy_test: 63.03317535545023 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.34996041171813, accuracy_test: 62.796208530805686 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.89865399841647, accuracy_test: 53.08056872037915 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.561361836896275, accuracy_test: 54.02843601895735 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.986539984164686, accuracy_test: 57.58293838862559 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.14172604908947, accuracy_test: 64.92890995260665 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.1741884402217, accuracy_test: 56.872037914691944 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.186064924782265, accuracy_test: 45.7345971563981 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 54.315122723673795, accuracy_test: 49.28909952606635 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.92478226444972, accuracy_test: 62.32227488151659 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.94536817102138, accuracy_test: 59.0047393364929 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.30324623911323, accuracy_test: 54.976303317535546 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.048297703879655, accuracy_test: 46.208530805687204 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 52.414885193982585, accuracy_test: 48.81516587677725 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.99841646872525, accuracy_test: 45.26066350710901 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.8368962787015, accuracy_test: 54.976303317535546 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.027711797308, accuracy_test: 53.79146919431279 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.391132224861444, accuracy_test: 55.45023696682464 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.482185273159146, accuracy_test: 49.763033175355446 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.027711797308, accuracy_test: 51.18483412322274 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.798891528107674, accuracy_test: 50.4739336492891 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.10688836104512, accuracy_test: 48.1042654028436 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 50.51464766429137, accuracy_test: 47.39336492890995 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 46.00158353127474, accuracy_test: 42.89099526066351 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 56.927949326999205, accuracy_test: 51.65876777251185 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.819477434679335, accuracy_test: 55.45023696682464 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.432304038004744, accuracy_test: 53.55450236966824 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 54.63182897862233, accuracy_test: 51.18483412322274 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 49.6437054631829, accuracy_test: 42.18009478672986 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 48.69358669833729, accuracy_test: 47.39336492890995 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.95724465558195, accuracy_test: 53.55450236966824 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.64053840063341, accuracy_test: 50.71090047393365 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 52.01900237529691, accuracy_test: 52.3696682464455 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.027711797308, accuracy_test: 51.8957345971564 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.10134600158353, accuracy_test: 41.23222748815166 with 3 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.69912905779889, accuracy_test: 56.39810426540285 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.32066508313538, accuracy_test: 63.74407582938388 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.91290577988916, accuracy_test: 62.796208530805686 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.024544734758514, accuracy_test: 58.767772511848335 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.576405384006335, accuracy_test: 41.943127962085306 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.490894695170226, accuracy_test: 59.241706161137444 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.87490102929533, accuracy_test: 64.92890995260665 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.35866983372921, accuracy_test: 63.74407582938388 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.9366587490103, accuracy_test: 57.81990521327014 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.64053840063341, accuracy_test: 54.739336492891 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.09501187648456, accuracy_test: 60.426540284360186 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.86302454473476, accuracy_test: 66.11374407582939 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.10372129849564, accuracy_test: 59.71563981042654 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.00395882818685, accuracy_test: 61.37440758293838 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.92478226444972, accuracy_test: 56.16113744075829 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.7458432304038, accuracy_test: 62.32227488151659 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.71654790182106, accuracy_test: 63.98104265402843 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.30007917656373, accuracy_test: 61.37440758293838 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 45.13064133016627, accuracy_test: 43.3649289099526 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 53.36500395882818, accuracy_test: 47.39336492890995 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.08313539192399, accuracy_test: 60.90047393364929 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.7957244655582, accuracy_test: 64.21800947867298 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.99208234362628, accuracy_test: 61.61137440758294 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.73713380839272, accuracy_test: 59.241706161137444 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.74030087094221, accuracy_test: 53.08056872037915 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.72842438638163, accuracy_test: 61.37440758293838 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.73396674584322, accuracy_test: 69.66824644549763 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.34125098970704, accuracy_test: 60.426540284360186 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.57878068091844, accuracy_test: 58.767772511848335 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.8456057007126, accuracy_test: 59.95260663507109 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.93349168646081, accuracy_test: 63.98104265402843 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 34.600158353127476, accuracy_test: 31.990521327014214 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.42913697545526, accuracy_test: 62.55924170616114 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 36.42121931908155, accuracy_test: 31.753554502369667 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 38.95486935866984, accuracy_test: 31.04265402843602 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.995249406175766, accuracy_test: 53.317535545023695 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.93349168646081, accuracy_test: 64.92890995260665 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.72842438638163, accuracy_test: 56.872037914691944 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.977830562153606, accuracy_test: 51.18483412322274 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.42042755344418, accuracy_test: 56.39810426540285 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.31195566112431, accuracy_test: 56.6350710900474 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.995249406175766, accuracy_test: 55.92417061611374 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.44972288202692, accuracy_test: 55.21327014218009 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 47.58511480601742, accuracy_test: 43.127962085308056 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 52.96912114014252, accuracy_test: 46.44549763033176 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.24465558194775, accuracy_test: 52.3696682464455 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.60807600950119, accuracy_test: 63.74407582938388 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.47030878859857, accuracy_test: 53.08056872037915 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.66983372921615, accuracy_test: 55.45023696682464 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 50.67300079176563, accuracy_test: 46.208530805687204 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 52.09817893903404, accuracy_test: 45.97156398104265 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 54.07759303246239, accuracy_test: 48.5781990521327 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.718131433095804, accuracy_test: 11.848341232227488 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 52.96912114014252, accuracy_test: 50.4739336492891 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.46159936658749, accuracy_test: 54.2654028436019 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.813935075217735, accuracy_test: 41.70616113744076 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.37054631828978, accuracy_test: 63.270142180094794 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.09184481393508, accuracy_test: 62.08530805687204 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.57007125890736, accuracy_test: 55.687203791469194 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 56.690419635787805, accuracy_test: 54.976303317535546 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.69912905779889, accuracy_test: 59.47867298578199 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.3673792557403, accuracy_test: 70.37914691943128 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.8456057007126, accuracy_test: 64.21800947867298 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.80443388756929, accuracy_test: 67.06161137440758 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.60807600950119, accuracy_test: 57.81990521327014 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.51702296120348, accuracy_test: 67.77251184834124 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.4972288202692, accuracy_test: 43.838862559241704 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.63737133808392, accuracy_test: 59.71563981042654 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.353127474267616, accuracy_test: 54.2654028436019 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.51148060174188, accuracy_test: 55.21327014218009 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.95407759303247, accuracy_test: 60.18957345971564 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.74267616785431, accuracy_test: 70.61611374407583 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.24148851939826, accuracy_test: 63.74407582938388 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.77513855898654, accuracy_test: 65.40284360189574 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.56690419635788, accuracy_test: 64.21800947867298 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.51702296120348, accuracy_test: 64.69194312796208 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.45843230403801, accuracy_test: 63.270142180094794 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.02137767220903, accuracy_test: 64.45497630331754 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.418052256532064, accuracy_test: 42.89099526066351 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.819477434679335, accuracy_test: 54.2654028436019 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.63737133808392, accuracy_test: 61.137440758293835 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.71338083927158, accuracy_test: 72.74881516587678 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.1797307996833, accuracy_test: 66.58767772511848 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.78384798099762, accuracy_test: 64.69194312796208 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.44972288202692, accuracy_test: 60.426540284360186 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.94536817102138, accuracy_test: 59.0047393364929 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.06571654790183, accuracy_test: 54.739336492891 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 44.89311163895487, accuracy_test: 44.54976303317535 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.30878859857482, accuracy_test: 66.58767772511848 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.91290577988916, accuracy_test: 66.11374407582939 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.024544734758514, accuracy_test: 58.53080568720379 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.87173396674585, accuracy_test: 72.03791469194313 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.37925574030086, accuracy_test: 64.45497630331754 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.45843230403801, accuracy_test: 63.270142180094794 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.72842438638163, accuracy_test: 53.55450236966824 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.96278701504355, accuracy_test: 67.06161137440758 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.38242280285036, accuracy_test: 55.21327014218009 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.01266825019793, accuracy_test: 63.74407582938388 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 56.294536817102134, accuracy_test: 52.60663507109005 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.74901029295329, accuracy_test: 56.872037914691944 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.00395882818685, accuracy_test: 60.66350710900474 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.43784639746636, accuracy_test: 67.77251184834124 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.87490102929533, accuracy_test: 58.767772511848335 with 4 features and 9 layers
# Start Training
# /home/menna/miniconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Finished Fitting
# accuracy_train: 71.41726049089469, accuracy_test: 67.06161137440758 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.60807600950119, accuracy_test: 61.37440758293838 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.895486935866984, accuracy_test: 58.0568720379147 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 55.5027711797308, accuracy_test: 51.421800947867304 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 37.13380839271576, accuracy_test: 32.93838862559242 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.96595407759303, accuracy_test: 54.502369668246445 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.17102137767222, accuracy_test: 64.69194312796208 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.9366587490103, accuracy_test: 53.08056872037915 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.21219319081551, accuracy_test: 63.74407582938388 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.54077593032462, accuracy_test: 54.739336492891 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.47901821060967, accuracy_test: 61.37440758293838 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.40300870942201, accuracy_test: 50.0 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.82818685669042, accuracy_test: 51.18483412322274 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.93349168646081, accuracy_test: 61.37440758293838 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.64053840063341, accuracy_test: 52.60663507109005 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.72842438638163, accuracy_test: 56.872037914691944 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.55819477434679, accuracy_test: 58.767772511848335 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.857482185273156, accuracy_test: 53.55450236966824 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.04513064133017, accuracy_test: 57.345971563981045 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.72842438638163, accuracy_test: 59.241706161137444 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.68725257323833, accuracy_test: 62.796208530805686 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.323832145684875, accuracy_test: 54.02843601895735 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.16231195566112, accuracy_test: 62.08530805687204 with 4 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.45843230403801, accuracy_test: 68.72037914691943 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.09184481393508, accuracy_test: 65.63981042654028 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.07442596991291, accuracy_test: 57.81990521327014 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.11559778305622, accuracy_test: 57.345971563981045 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 62.23277909738717, accuracy_test: 61.137440758293835 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.0387965162312, accuracy_test: 74.40758293838863 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.97149643705463, accuracy_test: 68.95734597156398 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.38796516231196, accuracy_test: 68.48341232227489 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.94220110847189, accuracy_test: 66.35071090047393 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.25890736342043, accuracy_test: 69.90521327014217 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.51702296120348, accuracy_test: 64.92890995260665 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.76326207442597, accuracy_test: 67.53554502369668 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.59065716547902, accuracy_test: 56.16113744075829 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.37054631828978, accuracy_test: 59.47867298578199 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.00395882818685, accuracy_test: 63.98104265402843 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.24703087885986, accuracy_test: 73.22274881516587 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.76642913697546, accuracy_test: 65.40284360189574 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.646080760095, accuracy_test: 65.87677725118483 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.22961203483769, accuracy_test: 65.87677725118483 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.1298495645289, accuracy_test: 67.77251184834124 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.51702296120348, accuracy_test: 61.61137440758294 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.41726049089469, accuracy_test: 67.29857819905213 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.64053840063341, accuracy_test: 55.21327014218009 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.44101346001584, accuracy_test: 58.29383886255924 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.08313539192399, accuracy_test: 63.270142180094794 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.53444180522565, accuracy_test: 74.17061611374407 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.91290577988916, accuracy_test: 67.06161137440758 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.76326207442597, accuracy_test: 67.53554502369668 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 56.215360253365, accuracy_test: 53.08056872037915 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.57878068091844, accuracy_test: 58.767772511848335 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.94220110847189, accuracy_test: 63.507109004739334 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.25019794140934, accuracy_test: 63.98104265402843 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.20902612826603, accuracy_test: 64.69194312796208 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.50514647664292, accuracy_test: 68.00947867298578 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.54077593032462, accuracy_test: 54.976303317535546 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.326207442597, accuracy_test: 72.27488151658767 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.96278701504355, accuracy_test: 67.06161137440758 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.83372921615202, accuracy_test: 68.72037914691943 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.67537608867775, accuracy_test: 65.16587677725119 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.10926365795724, accuracy_test: 66.35071090047393 with 5 features and 9 layers
# Start Training
# /home/menna/miniconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Finished Fitting
# accuracy_train: 68.72525732383214, accuracy_test: 62.55924170616114 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.49643705463184, accuracy_test: 65.63981042654028 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 57.08630245447348, accuracy_test: 54.502369668246445 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.25336500395883, accuracy_test: 58.29383886255924 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.16231195566112, accuracy_test: 63.03317535545023 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.21773555027713, accuracy_test: 73.22274881516587 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.81631037212985, accuracy_test: 61.84834123222749 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.282660332541575, accuracy_test: 57.81990521327014 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 56.13618368962787, accuracy_test: 51.8957345971564 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.05384006334126, accuracy_test: 57.58293838862559 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.81631037212985, accuracy_test: 55.687203791469194 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.80443388756929, accuracy_test: 65.16587677725119 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.6547901821061, accuracy_test: 69.43127962085308 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.92161520190024, accuracy_test: 67.29857819905213 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.66983372921615, accuracy_test: 50.71090047393365 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.71338083927158, accuracy_test: 69.19431279620854 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.38796516231196, accuracy_test: 62.55924170616114 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.92478226444972, accuracy_test: 60.66350710900474 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 58.59065716547902, accuracy_test: 54.2654028436019 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.10372129849564, accuracy_test: 57.345971563981045 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.32937450514648, accuracy_test: 61.61137440758294 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 63.73713380839272, accuracy_test: 58.29383886255924 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.40855106888361, accuracy_test: 61.84834123222749 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.40855106888361, accuracy_test: 61.61137440758294 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 56.927949326999205, accuracy_test: 50.947867298578196 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.90419635787806, accuracy_test: 58.767772511848335 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.48772763262075, accuracy_test: 64.92890995260665 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.35866983372921, accuracy_test: 65.63981042654028 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.5993665874901, accuracy_test: 55.45023696682464 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.37054631828978, accuracy_test: 59.95260663507109 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.29691211401425, accuracy_test: 69.43127962085308 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.2209026128266, accuracy_test: 65.87677725118483 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.32937450514648, accuracy_test: 66.82464454976304 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.32066508313538, accuracy_test: 61.61137440758294 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.81314330958037, accuracy_test: 69.19431279620854 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.77513855898654, accuracy_test: 61.84834123222749 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.72525732383214, accuracy_test: 63.98104265402843 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 56.848772763262076, accuracy_test: 54.739336492891 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 61.91607284243864, accuracy_test: 58.0568720379147 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.47901821060967, accuracy_test: 61.84834123222749 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.48456057007125, accuracy_test: 72.03791469194313 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.37608867775138, accuracy_test: 71.09004739336493 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.18844022169438, accuracy_test: 69.66824644549763 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.14172604908947, accuracy_test: 63.74407582938388 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.87490102929533, accuracy_test: 61.61137440758294 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.92161520190024, accuracy_test: 67.29857819905213 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.07125890736341, accuracy_test: 67.06161137440758 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.3673792557403, accuracy_test: 69.66824644549763 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.66349960411718, accuracy_test: 69.90521327014217 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.92478226444972, accuracy_test: 62.08530805687204 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.43467933491686, accuracy_test: 73.45971563981043 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.2763262074426, accuracy_test: 72.98578199052133 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.18844022169438, accuracy_test: 68.95734597156398 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.07125890736341, accuracy_test: 67.29857819905213 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.39984164687253, accuracy_test: 61.37440758293838 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.62549485352335, accuracy_test: 65.16587677725119 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.1797307996833, accuracy_test: 67.53554502369668 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.52573238321457, accuracy_test: 69.43127962085308 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.34679334916865, accuracy_test: 69.19431279620854 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.60807600950119, accuracy_test: 61.84834123222749 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.51702296120348, accuracy_test: 66.11374407582939 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.34679334916865, accuracy_test: 72.27488151658767 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.88044338875693, accuracy_test: 72.74881516587678 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.07125890736341, accuracy_test: 68.48341232227489 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.08867775138559, accuracy_test: 74.40758293838863 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.72209026128266, accuracy_test: 75.59241706161137 with 5 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.78384798099762, accuracy_test: 66.35071090047393 with 5 features and 9 layers
# Start Training
# Finished Fitting
# ...
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.87490102929533, accuracy_test: 62.796208530805686 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.9889152810768, accuracy_test: 75.59241706161137 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.10926365795724, accuracy_test: 71.32701421800948 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.20902612826603, accuracy_test: 64.69194312796208 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.55819477434679, accuracy_test: 61.137440758293835 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.52889944576405, accuracy_test: 56.6350710900474 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.52573238321457, accuracy_test: 67.29857819905213 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.74267616785431, accuracy_test: 68.00947867298578 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 59.54077593032462, accuracy_test: 54.2654028436019 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.93903404592241, accuracy_test: 75.35545023696683 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.2763262074426, accuracy_test: 72.03791469194313 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.95407759303247, accuracy_test: 63.98104265402843 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.43784639746636, accuracy_test: 63.98104265402843 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.30878859857482, accuracy_test: 68.00947867298578 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.60490894695171, accuracy_test: 67.53554502369668 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.40538400633412, accuracy_test: 70.61611374407583 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.96595407759303, accuracy_test: 54.502369668246445 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.06809184481394, accuracy_test: 74.40758293838863 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.54631828978623, accuracy_test: 67.06161137440758 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.54315122723673, accuracy_test: 75.11848341232228 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.43784639746636, accuracy_test: 66.82464454976304 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.69279493269993, accuracy_test: 68.24644549763033 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 80.28503562945369, accuracy_test: 78.90995260663507 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.67220902612827, accuracy_test: 72.27488151658767 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.95407759303247, accuracy_test: 60.426540284360186 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.24148851939826, accuracy_test: 61.84834123222749 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.22961203483769, accuracy_test: 66.11374407582939 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.0799683293745, accuracy_test: 69.90521327014217 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 11.559778305621537, accuracy_test: 11.61137440758294 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.03008709422011, accuracy_test: 67.77251184834124 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.63737133808392, accuracy_test: 63.74407582938388 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.85114806017418, accuracy_test: 71.80094786729858 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.0332541567696, accuracy_test: 65.16587677725119 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.5637371338084, accuracy_test: 72.03791469194313 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.55819477434679, accuracy_test: 61.137440758293835 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.0387965162312, accuracy_test: 74.17061611374407 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.10926365795724, accuracy_test: 69.90521327014217 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.71654790182106, accuracy_test: 60.90047393364929 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.00079176563737, accuracy_test: 67.29857819905213 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.45843230403801, accuracy_test: 60.18957345971564 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.86302454473476, accuracy_test: 65.87677725118483 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.23832145684878, accuracy_test: 69.43127962085308 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.95961995249407, accuracy_test: 73.69668246445498 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.40538400633412, accuracy_test: 71.32701421800948 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.02137767220903, accuracy_test: 65.87677725118483 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.09184481393508, accuracy_test: 65.40284360189574 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 65.08313539192399, accuracy_test: 61.137440758293835 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.39667458432304, accuracy_test: 68.24644549763033 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 43.62628661916072, accuracy_test: 41.23222748815166 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.76642913697546, accuracy_test: 59.241706161137444 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.58432304038006, accuracy_test: 68.72037914691943 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.57007125890736, accuracy_test: 53.55450236966824 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.48456057007125, accuracy_test: 74.40758293838863 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.6547901821061, accuracy_test: 69.66824644549763 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.18844022169438, accuracy_test: 69.90521327014217 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.76326207442597, accuracy_test: 67.77251184834124 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.08867775138559, accuracy_test: 73.45971563981043 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.59303246239114, accuracy_test: 75.11848341232228 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.78068091844814, accuracy_test: 75.82938388625593 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.65162311955662, accuracy_test: 76.06635071090048 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.37925574030086, accuracy_test: 62.08530805687204 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 72.28820269200317, accuracy_test: 63.98104265402843 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 81.39350752177356, accuracy_test: 78.43601895734598 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.4639746634996, accuracy_test: 75.11848341232228 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.67220902612827, accuracy_test: 74.40758293838863 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.85985748218528, accuracy_test: 76.30331753554502 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.81314330958037, accuracy_test: 66.11374407582939 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.37608867775138, accuracy_test: 71.80094786729858 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 81.55186064924781, accuracy_test: 75.82938388625593 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.83056215360253, accuracy_test: 72.98578199052133 with 6 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.9889152810768, accuracy_test: 75.82938388625593 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.42596991290577, accuracy_test: 71.56398104265402 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 67.06254948535233, accuracy_test: 61.84834123222749 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.13301662707839, accuracy_test: 62.08530805687204 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 51.86064924782264, accuracy_test: 47.6303317535545 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.97149643705463, accuracy_test: 67.53554502369668 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.49643705463184, accuracy_test: 69.19431279620854 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.68725257323833, accuracy_test: 60.18957345971564 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.8867775138559, accuracy_test: 54.739336492891 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 60.96595407759303, accuracy_test: 55.21327014218009 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 75.93032462391133, accuracy_test: 71.56398104265402 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.19160728424386, accuracy_test: 60.90047393364929 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.33491686460808, accuracy_test: 76.54028436018957 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 69.27949326999209, accuracy_test: 65.87677725118483 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.43467933491686, accuracy_test: 74.40758293838863 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.33491686460808, accuracy_test: 76.54028436018957 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.26761678543151, accuracy_test: 71.80094786729858 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.01821060965955, accuracy_test: 77.25118483412322 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.95091053048297, accuracy_test: 69.66824644549763 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.13301662707839, accuracy_test: 59.0047393364929 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.38479809976246, accuracy_test: 77.25118483412322 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 68.56690419635788, accuracy_test: 65.87677725118483 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.62232779097387, accuracy_test: 77.72511848341233 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.88915281076801, accuracy_test: 77.48815165876776 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 73.71338083927158, accuracy_test: 69.90521327014217 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 51.22723673792557, accuracy_test: 46.208530805687204 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.73079968329374, accuracy_test: 75.59241706161137 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.35550277117973, accuracy_test: 72.98578199052133 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 71.10055423594616, accuracy_test: 69.66824644549763 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.38796516231196, accuracy_test: 66.82464454976304 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.30562153602534, accuracy_test: 74.64454976303317 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 66.5083135391924, accuracy_test: 60.66350710900474 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 64.52889944576405, accuracy_test: 60.66350710900474 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 83.1353919239905, accuracy_test: 78.19905213270142 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 81.94774346793349, accuracy_test: 79.38388625592417 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 82.34362628661917, accuracy_test: 77.96208530805687 with 7 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.25574030087094, accuracy_test: 74.64454976303317 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.57244655581948, accuracy_test: 77.96208530805687 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.96832937450515, accuracy_test: 76.77725118483413 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 74.03008709422011, accuracy_test: 71.56398104265402 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 46.714172604908946, accuracy_test: 44.78672985781991 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 77.513855898654, accuracy_test: 73.69668246445498 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 78.38479809976246, accuracy_test: 75.59241706161137 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 76.88044338875693, accuracy_test: 75.59241706161137 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 79.01821060965955, accuracy_test: 76.54028436018957 with 8 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 82.42280285035629, accuracy_test: 80.33175355450237 with 9 features and 9 layers

# %%
accuracy = Train_NN(X,Y,9)
accuracy = Train_NN(X,Y,10)
accuracy = Train_NN(X,Y,11)
accuracy = Train_NN(X,Y,12)
# Out:
# Start Training
# Finished Fitting
# accuracy_train: 82.42280285035629, accuracy_test: 80.33175355450237 with 9 features and 9 layers
# Start Training
# Finished Fitting
# accuracy_train: 70.62549485352335, accuracy_test: 67.29857819905213 with 9 features and 10 layers
# Start Training
# Finished Fitting
# accuracy_train: 83.92715756136184, accuracy_test: 78.90995260663507 with 9 features and 11 layers
# Start Training
# Finished Fitting
# accuracy_train: 84.16468725257323, accuracy_test: 81.04265402843602 with 9 features and 12 layers

# %%
accuracy = Train_NN(X,Y,16)
accuracy = Train_NN(X,Y,14)
# Out:
# Start Training
# Finished Fitting
# accuracy_train: 85.74821852731591, accuracy_test: 80.09478672985783 with 9 features and 16 layers
# Start Training
# Finished Fitting
# accuracy_train: 84.79809976247031, accuracy_test: 80.33175355450237 with 9 features and 14 layers

# %%
X = np.array(X)
Y = np.array(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=4, stratify=Y)
print("training size:",x_train.shape)

# %%
clf = MLPClassifier(alpha=1e-05, hidden_layer_sizes=(9), random_state=1,solver='lbfgs',max_iter=10000)
clf = clf.fit(x_train, y_train)
print("Finished Fitting")

# %%
import matplotlib.pyplot as plt
test_idx=7
plt.show()
y_pred = clf.predict(x_test)
y_pred_prop = clf.predict_proba(x_test)
accuracy = np.mean(y_test==y_pred)
print(y_pred_prop[test_idx],y_pred[test_idx],y_test[test_idx])
y_axis = list(range(1,10))
plt.bar(y_axis, y_pred_prop[test_idx], color ='green')
print(y_axis)
plt.show()
print("accuracy: ",accuracy*100)
